# %% [markdown]
# # Machine Learning for Single-Cell Biology Workshop
# ## Arian Amani
# Data Scientist | Wellcome Sanger Institute | Sapienza University of Rome
# * [LinkedIn](https://www.linkedin.com/in/arianamani/)
# * [GitHub](https://github.com/ArianAmani)
# * [Website](https://arianamani.github.io/)

# %% [markdown]
# ## 8. Applications of Deep Learning in Single-Cell Biology
# Now that we have seen how some of these deep learning models are implemented, let's see the way they're actually used in practice in our field!
#
# This section is going to be mostly me explaining some interesting tasks that are being tackled using deep learning.

# %% [markdown]
# ### Integration of Single-Cell Datasets with VAEs
#
# **I'm going to explain the concept of "Transfer Learning"** --> [CS231n Notes, Page 81](https://cs231n.stanford.edu/slides/2024/lecture_6_part_1.pdf)
#
# Now, let's overview [scArches](https://www.nature.com/articles/s41587-021-01001-7)

# %% [markdown]
# ### Perturbation Prediction Models
#
# * Perturbations: CRISPR, Stimulation, ...
# * Drugs (Molecule representation...)
#
# Let's go over [scGen](https://www.nature.com/articles/s41592-019-0494-8) a bit
#
# ![Screenshot from 2024-10-24 13-32-53.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 9. Case Study
# * GEARS
# * CPA
# * Hyperparameter Tuning

# %% [markdown]
# ### [GEARS](https://www.nature.com/articles/s41587-023-01905-6)

# %% [markdown]
# ### [CPA](https://www.embopress.org/doi/full/10.15252/msb.202211517)
#
# Let's overview the some code here:
# * [Notebook 1, Norman](https://colab.research.google.com/github/theislab/cpa/blob/master/docs/tutorials/Norman.ipynb)
# * [Notebook 2, Batch Effect](https://colab.research.google.com/github/theislab/cpa/blob/master/docs/tutorials/Batch_correction_in_expression_space.ipynb)

# %% [markdown]
# ### Hyperparameter Tuning
#
# First, we will look at the Ray framework and it's docs, talking about why hyperparameter tuning is important and useful.
# * [Ray Tune](https://docs.ray.io/en/latest/tune/key-concepts.html)
#
# Next, let's look at some actual reports and examples from a real research project on WandB. (This is from an ongoing project, unfortunatly I can't share links)
