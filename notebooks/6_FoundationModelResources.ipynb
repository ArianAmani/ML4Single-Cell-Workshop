# %% [markdown]
# <a href="https://colab.research.google.com/github/ArianAmani/ML4Single-Cell-Workshop/blob/main/notebooks/6_FoundationModelResources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning for Single-Cell Biology Workshop
# ## Arian Amani
# Data Scientist | Wellcome Sanger Institute | Sapienza University of Rome
# * [LinkedIn](https://www.linkedin.com/in/arianamani/)
# * [GitHub](https://github.com/ArianAmani)
# * [Website](https://arianamani.github.io/)

# %% [markdown]
# ## 10. Foundation Models
# * Geneformer
# * scGPT
# * Fine-Tuning Foundation Models

# %% [markdown]
# ### Quick overview of Transformers
# * Self Attention
# ![image.png](data:image/png;base64,...)
# * Influence (ChatGPT)
# * Problems: Tokenization in Single-Cell, Computation Cost

# %% [markdown]
# Let's head over to scGPT's example notebook to see how it works: [Link](https://colab.research.google.com/github/bowang-lab/scGPT/blob/main/tutorials/zero-shot/Tutorial_ZeroShot_Reference_Mapping.ipynb)

# %% [markdown]
# But we want to probably fine tune these models. Check out [PEFT](https://huggingface.co/docs/peft/en/index) later!

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
